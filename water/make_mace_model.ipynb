# %%
# %pip install -U pip
# %pip install -U setuptools
# %pip install ase
# Out:
# Requirement already satisfied: pip in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (23.0.1)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#      ------------- -------------------------- 0.6/1.8 MB 19.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 1.6/1.8 MB 20.1 MB/s eta 0:00:01
#      ---------------------------------------- 1.8/1.8 MB 19.3 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-25.1.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: setuptools in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (65.5.0)
# Collecting setuptools
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 30.3 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
# Successfully installed setuptools-80.9.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting aseNote: you may need to restart the kernel to use updated packages.
#
#   Downloading ase-3.25.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting numpy>=1.19.5 (from ase)
#   Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting scipy>=1.6.0 (from ase)
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting matplotlib>=3.3.4 (from ase)
#   Downloading matplotlib-3.10.3-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.4->ase)
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.4->ase)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.4->ase)
#   Downloading fonttools-4.59.0-cp310-cp310-win_amd64.whl.metadata (110 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.4->ase)
#   Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from matplotlib>=3.3.4->ase) (25.0)
# Collecting pillow>=8 (from matplotlib>=3.3.4->ase)
#   Downloading pillow-11.3.0-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3.4->ase)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from matplotlib>=3.3.4->ase) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase) (1.17.0)
# Downloading ase-3.25.0-py3-none-any.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------------------- 3.0/3.0 MB 34.5 MB/s eta 0:00:00
# Downloading matplotlib-3.10.3-cp310-cp310-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 38.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.0-cp310-cp310-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 31.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ----------------- ---------------------- 5.8/12.9 MB 27.1 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 27.9 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp310-cp310-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 39.1 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ------ --------------------------------- 6.3/41.3 MB 32.1 MB/s eta 0:00:02
#    --------- ------------------------------ 9.4/41.3 MB 22.6 MB/s eta 0:00:02
#    --------------- ------------------------ 15.7/41.3 MB 24.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 23.3/41.3 MB 27.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 30.7/41.3 MB 29.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.7/41.3 MB 28.8 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.3 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------- 41.3/41.3 MB 27.6 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, scipy, contourpy, matplotlib, ase
#
#    ---- -----------------------------------  1/10 [pillow]
#    ---- -----------------------------------  1/10 [pillow]
#    ---- -----------------------------------  1/10 [pillow]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ------------------------------------ ---  9/10 [ase]
#    ---------------------------------------- 10/10 [ase]
#
# Successfully installed ase-3.25.0 contourpy-1.3.2 cycler-0.12.1 fonttools-4.59.0 kiwisolver-1.4.8 matplotlib-3.10.3 numpy-2.2.6 pillow-11.3.0 pyparsing-3.2.3 scipy-1.15.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yvl 2024.9.17 requires h5py, which is not installed.
# yvl 2024.9.17 requires mp-api, which is not installed.
# yvl 2024.9.17 requires phonopy, which is not installed.
# yvl 2024.9.17 requires pymatgen, which is not installed.
# yvl 2024.9.17 requires scikit-image, which is not installed.
# yvl 2024.9.17 requires scikit-learn, which is not installed.
# yvl 2024.9.17 requires seekpath, which is not installed.
# yvl 2024.9.17 requires typer, which is not installed.

# %%
# %pip uninstall -y mace-torch torch torchvision torchaudio
# %pip cache purge
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# %pip install mace-torch
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping mace-torch as it is not installed.
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Files removed: 138 (102.6 MB)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu126/torch-2.7.1%2Bcu126-cp310-cp310-win_amd64.whl.metadata (27 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu126/torchvision-0.22.1%2Bcu126-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu126/torchaudio-2.7.1%2Bcu126-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Collecting filelock (from torch)
#   Downloading https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from torch) (4.14.1)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch)
#   Downloading https://download.pytorch.org/whl/Jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from torchvision) (11.3.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      ------------------------------------- 536.2/536.2 kB 18.3 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Downloading https://download.pytorch.org/whl/cu126/torch-2.7.1%2Bcu126-cp310-cp310-win_amd64.whl (2716.9 MB)
#    ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 GB 76.2 MB/s eta 0:00:36
#    ---------------------------------------- 0.0/2.7 GB 69.1 MB/s eta 0:00:39
#     --------------------------------------- 0.0/2.7 GB 69.2 MB/s eta 0:00:39
#     --------------------------------------- 0.1/2.7 GB 71.2 MB/s eta 0:00:38
#    - -------------------------------------- 0.1/2.7 GB 71.6 MB/s eta 0:00:37
#    - -------------------------------------- 0.1/2.7 GB 71.2 MB/s eta 0:00:37
#    - -------------------------------------- 0.1/2.7 GB 71.2 MB/s eta 0:00:37
#    - -------------------------------------- 0.1/2.7 GB 70.5 MB/s eta 0:00:37
#    - -------------------------------------- 0.1/2.7 GB 70.6 MB/s eta 0:00:37
#    -- ------------------------------------- 0.1/2.7 GB 70.5 MB/s eta 0:00:37
#    -- ------------------------------------- 0.2/2.7 GB 70.3 MB/s eta 0:00:37
#    -- ------------------------------------- 0.2/2.7 GB 70.1 MB/s eta 0:00:37
#    -- ------------------------------------- 0.2/2.7 GB 70.5 MB/s eta 0:00:36
#    --- ------------------------------------ 0.2/2.7 GB 71.3 MB/s eta 0:00:36
#    --- ------------------------------------ 0.2/2.7 GB 72.0 MB/s eta 0:00:35
#    --- ------------------------------------ 0.2/2.7 GB 72.6 MB/s eta 0:00:35
#    --- ------------------------------------ 0.3/2.7 GB 73.2 MB/s eta 0:00:34
#    ---- ----------------------------------- 0.3/2.7 GB 72.9 MB/s eta 0:00:34
#    ---- ----------------------------------- 0.3/2.7 GB 73.5 MB/s eta 0:00:33
#    ---- ----------------------------------- 0.3/2.7 GB 72.9 MB/s eta 0:00:34
#    ---- ----------------------------------- 0.3/2.7 GB 72.9 MB/s eta 0:00:33
#    ---- ----------------------------------- 0.3/2.7 GB 71.6 MB/s eta 0:00:34
#    ----- ---------------------------------- 0.3/2.7 GB 70.4 MB/s eta 0:00:34
#    ----- ---------------------------------- 0.4/2.7 GB 69.5 MB/s eta 0:00:34
#    ----- ---------------------------------- 0.4/2.7 GB 69.5 MB/s eta 0:00:34
#    ----- ---------------------------------- 0.4/2.7 GB 69.8 MB/s eta 0:00:34
#    ----- ---------------------------------- 0.4/2.7 GB 68.7 MB/s eta 0:00:34
#    ------ --------------------------------- 0.4/2.7 GB 68.7 MB/s eta 0:00:34
#    ------ --------------------------------- 0.4/2.7 GB 67.9 MB/s eta 0:00:34
#    ------ --------------------------------- 0.4/2.7 GB 67.0 MB/s eta 0:00:35
#    ------ --------------------------------- 0.4/2.7 GB 66.2 MB/s eta 0:00:35
#    ------ --------------------------------- 0.5/2.7 GB 65.5 MB/s eta 0:00:35
#    ------ --------------------------------- 0.5/2.7 GB 64.5 MB/s eta 0:00:35
#    ------- -------------------------------- 0.5/2.7 GB 64.5 MB/s eta 0:00:35
#    ------- -------------------------------- 0.5/2.7 GB 64.2 MB/s eta 0:00:35
#    ------- -------------------------------- 0.5/2.7 GB 63.7 MB/s eta 0:00:35
#    ------- -------------------------------- 0.5/2.7 GB 63.7 MB/s eta 0:00:35
#    -------- ------------------------------- 0.5/2.7 GB 63.7 MB/s eta 0:00:35
#    -------- ------------------------------- 0.6/2.7 GB 63.7 MB/s eta 0:00:34
#    -------- ------------------------------- 0.6/2.7 GB 63.5 MB/s eta 0:00:34
#    -------- ------------------------------- 0.6/2.7 GB 64.0 MB/s eta 0:00:34
#    -------- ------------------------------- 0.6/2.7 GB 64.2 MB/s eta 0:00:33
#    -------- ------------------------------- 0.6/2.7 GB 62.5 MB/s eta 0:00:34
#    --------- ------------------------------ 0.6/2.7 GB 61.2 MB/s eta 0:00:35
#    --------- ------------------------------ 0.6/2.7 GB 59.4 MB/s eta 0:00:36
#    --------- ------------------------------ 0.6/2.7 GB 58.4 MB/s eta 0:00:36
#    --------- ------------------------------ 0.6/2.7 GB 58.2 MB/s eta 0:00:36
#    --------- ------------------------------ 0.7/2.7 GB 58.0 MB/s eta 0:00:36
#    --------- ------------------------------ 0.7/2.7 GB 58.0 MB/s eta 0:00:36
#    --------- ------------------------------ 0.7/2.7 GB 58.4 MB/s eta 0:00:35
#    ---------- ----------------------------- 0.7/2.7 GB 58.8 MB/s eta 0:00:35
#    ---------- ----------------------------- 0.7/2.7 GB 58.2 MB/s eta 0:00:35
#    ---------- ----------------------------- 0.7/2.7 GB 58.0 MB/s eta 0:00:35
#    ---------- ----------------------------- 0.7/2.7 GB 59.0 MB/s eta 0:00:34
#    ---------- ----------------------------- 0.7/2.7 GB 59.2 MB/s eta 0:00:34
#    ----------- ---------------------------- 0.8/2.7 GB 58.8 MB/s eta 0:00:34
#    ----------- ---------------------------- 0.8/2.7 GB 59.2 MB/s eta 0:00:33
#    ----------- ---------------------------- 0.8/2.7 GB 59.6 MB/s eta 0:00:33
#    ----------- ---------------------------- 0.8/2.7 GB 59.4 MB/s eta 0:00:33
#    ------------ --------------------------- 0.8/2.7 GB 59.0 MB/s eta 0:00:33
#    ------------ --------------------------- 0.8/2.7 GB 58.6 MB/s eta 0:00:33
#    ------------ --------------------------- 0.8/2.7 GB 58.4 MB/s eta 0:00:33
#    ------------ --------------------------- 0.9/2.7 GB 58.4 MB/s eta 0:00:32
#    ------------ --------------------------- 0.9/2.7 GB 62.3 MB/s eta 0:00:30
#    ------------- -------------------------- 0.9/2.7 GB 65.7 MB/s eta 0:00:28
#    ------------- -------------------------- 0.9/2.7 GB 66.5 MB/s eta 0:00:28
#    ------------- -------------------------- 0.9/2.7 GB 66.8 MB/s eta 0:00:27
#    ------------- -------------------------- 0.9/2.7 GB 66.0 MB/s eta 0:00:28
#    ------------- -------------------------- 0.9/2.7 GB 65.5 MB/s eta 0:00:28
#    ------------- -------------------------- 0.9/2.7 GB 64.2 MB/s eta 0:00:28
#    -------------- ------------------------- 1.0/2.7 GB 65.2 MB/s eta 0:00:27
#    -------------- ------------------------- 1.0/2.7 GB 66.0 MB/s eta 0:00:27
#    -------------- ------------------------- 1.0/2.7 GB 65.2 MB/s eta 0:00:27
#    -------------- ------------------------- 1.0/2.7 GB 64.5 MB/s eta 0:00:27
#    -------------- ------------------------- 1.0/2.7 GB 64.2 MB/s eta 0:00:27
#    --------------- ------------------------ 1.0/2.7 GB 63.7 MB/s eta 0:00:27
#    --------------- ------------------------ 1.0/2.7 GB 63.0 MB/s eta 0:00:27
#    --------------- ------------------------ 1.1/2.7 GB 61.9 MB/s eta 0:00:27
#    --------------- ------------------------ 1.1/2.7 GB 60.9 MB/s eta 0:00:28
#    --------------- ------------------------ 1.1/2.7 GB 60.7 MB/s eta 0:00:28
#    --------------- ------------------------ 1.1/2.7 GB 59.9 MB/s eta 0:00:28
#    ---------------- ----------------------- 1.1/2.7 GB 59.9 MB/s eta 0:00:28
#    ---------------- ----------------------- 1.1/2.7 GB 60.3 MB/s eta 0:00:27
#    ---------------- ----------------------- 1.1/2.7 GB 60.3 MB/s eta 0:00:27
#    ---------------- ----------------------- 1.1/2.7 GB 59.9 MB/s eta 0:00:27
#    ---------------- ----------------------- 1.2/2.7 GB 59.2 MB/s eta 0:00:27
#    ----------------- ---------------------- 1.2/2.7 GB 58.6 MB/s eta 0:00:27
#    ----------------- ---------------------- 1.2/2.7 GB 57.4 MB/s eta 0:00:27
#    ----------------- ---------------------- 1.2/2.7 GB 57.6 MB/s eta 0:00:27
#    ----------------- ---------------------- 1.2/2.7 GB 57.8 MB/s eta 0:00:27
#    ----------------- ---------------------- 1.2/2.7 GB 58.4 MB/s eta 0:00:26
#    ------------------ --------------------- 1.2/2.7 GB 59.2 MB/s eta 0:00:26
#    ------------------ --------------------- 1.2/2.7 GB 59.7 MB/s eta 0:00:25
#    ------------------ --------------------- 1.3/2.7 GB 60.5 MB/s eta 0:00:25
#    ------------------ --------------------- 1.3/2.7 GB 60.1 MB/s eta 0:00:25
#    ------------------ --------------------- 1.3/2.7 GB 59.9 MB/s eta 0:00:24
#    ------------------ --------------------- 1.3/2.7 GB 56.8 MB/s eta 0:00:26
#    ------------------- -------------------- 1.3/2.7 GB 56.4 MB/s eta 0:00:26
#    ------------------- -------------------- 1.3/2.7 GB 56.1 MB/s eta 0:00:26
#    ------------------- -------------------- 1.3/2.7 GB 55.3 MB/s eta 0:00:26
#    ------------------- -------------------- 1.3/2.7 GB 55.9 MB/s eta 0:00:25
#    ------------------- -------------------- 1.3/2.7 GB 56.1 MB/s eta 0:00:25
#    ------------------- -------------------- 1.4/2.7 GB 57.6 MB/s eta 0:00:24
#    -------------------- ------------------- 1.4/2.7 GB 57.6 MB/s eta 0:00:24
#    -------------------- ------------------- 1.4/2.7 GB 57.2 MB/s eta 0:00:24
#    -------------------- ------------------- 1.4/2.7 GB 57.2 MB/s eta 0:00:24
#    -------------------- ------------------- 1.4/2.7 GB 56.6 MB/s eta 0:00:24
#    -------------------- ------------------- 1.4/2.7 GB 56.1 MB/s eta 0:00:24
#    -------------------- ------------------- 1.4/2.7 GB 54.9 MB/s eta 0:00:24
#    --------------------- ------------------ 1.4/2.7 GB 54.2 MB/s eta 0:00:24
#    --------------------- ------------------ 1.4/2.7 GB 54.8 MB/s eta 0:00:24
#    --------------------- ------------------ 1.5/2.7 GB 54.8 MB/s eta 0:00:24
#    --------------------- ------------------ 1.5/2.7 GB 54.4 MB/s eta 0:00:24
#    --------------------- ------------------ 1.5/2.7 GB 53.9 MB/s eta 0:00:24
#    --------------------- ------------------ 1.5/2.7 GB 53.0 MB/s eta 0:00:24
#    ---------------------- ----------------- 1.5/2.7 GB 52.1 MB/s eta 0:00:24
#    ---------------------- ----------------- 1.5/2.7 GB 51.4 MB/s eta 0:00:24
#    ---------------------- ----------------- 1.5/2.7 GB 50.5 MB/s eta 0:00:24
#    ---------------------- ----------------- 1.5/2.7 GB 49.9 MB/s eta 0:00:24
#    ---------------------- ----------------- 1.5/2.7 GB 50.0 MB/s eta 0:00:24
#    ---------------------- ----------------- 1.6/2.7 GB 52.4 MB/s eta 0:00:23
#    ----------------------- ---------------- 1.6/2.7 GB 52.7 MB/s eta 0:00:22
#    ----------------------- ---------------- 1.6/2.7 GB 53.9 MB/s eta 0:00:22
#    ----------------------- ---------------- 1.6/2.7 GB 53.7 MB/s eta 0:00:21
#    ----------------------- ---------------- 1.6/2.7 GB 54.4 MB/s eta 0:00:21
#    ----------------------- ---------------- 1.6/2.7 GB 54.1 MB/s eta 0:00:21
#    ------------------------ --------------- 1.6/2.7 GB 53.7 MB/s eta 0:00:21
#    ------------------------ --------------- 1.7/2.7 GB 54.2 MB/s eta 0:00:20
#    ------------------------ --------------- 1.7/2.7 GB 55.5 MB/s eta 0:00:19
#    ------------------------ --------------- 1.7/2.7 GB 57.6 MB/s eta 0:00:18
#    ------------------------- -------------- 1.7/2.7 GB 60.3 MB/s eta 0:00:17
#    ------------------------- -------------- 1.7/2.7 GB 61.6 MB/s eta 0:00:17
#    ------------------------- -------------- 1.7/2.7 GB 63.0 MB/s eta 0:00:16
#    ------------------------- -------------- 1.7/2.7 GB 64.2 MB/s eta 0:00:16
#    ------------------------- -------------- 1.8/2.7 GB 66.2 MB/s eta 0:00:15
#    -------------------------- ------------- 1.8/2.7 GB 69.0 MB/s eta 0:00:14
#    -------------------------- ------------- 1.8/2.7 GB 70.1 MB/s eta 0:00:14
#    -------------------------- ------------- 1.8/2.7 GB 70.7 MB/s eta 0:00:13
#    -------------------------- ------------- 1.8/2.7 GB 71.0 MB/s eta 0:00:13
#    --------------------------- ------------ 1.8/2.7 GB 71.0 MB/s eta 0:00:13
#    --------------------------- ------------ 1.9/2.7 GB 72.9 MB/s eta 0:00:12
#    --------------------------- ------------ 1.9/2.7 GB 72.9 MB/s eta 0:00:12
#    --------------------------- ------------ 1.9/2.7 GB 73.2 MB/s eta 0:00:12
#    --------------------------- ------------ 1.9/2.7 GB 73.5 MB/s eta 0:00:12
#    ---------------------------- ----------- 1.9/2.7 GB 73.2 MB/s eta 0:00:11
#    ---------------------------- ----------- 1.9/2.7 GB 73.2 MB/s eta 0:00:11
#    ---------------------------- ----------- 1.9/2.7 GB 73.5 MB/s eta 0:00:11
#    ---------------------------- ----------- 2.0/2.7 GB 73.2 MB/s eta 0:00:11
#    ----------------------------- ---------- 2.0/2.7 GB 72.9 MB/s eta 0:00:11
#    ----------------------------- ---------- 2.0/2.7 GB 72.9 MB/s eta 0:00:10
#    ----------------------------- ---------- 2.0/2.7 GB 73.2 MB/s eta 0:00:10
#    ----------------------------- ---------- 2.0/2.7 GB 72.6 MB/s eta 0:00:10
#    ------------------------------ --------- 2.0/2.7 GB 72.2 MB/s eta 0:00:10
#    ------------------------------ --------- 2.1/2.7 GB 72.6 MB/s eta 0:00:10
#    ------------------------------ --------- 2.1/2.7 GB 72.9 MB/s eta 0:00:09
#    ------------------------------ --------- 2.1/2.7 GB 72.9 MB/s eta 0:00:09
#    ------------------------------ --------- 2.1/2.7 GB 71.6 MB/s eta 0:00:09
#    ------------------------------ --------- 2.1/2.7 GB 69.3 MB/s eta 0:00:09
#    ------------------------------ --------- 2.1/2.7 GB 66.8 MB/s eta 0:00:10
#    ------------------------------- -------- 2.1/2.7 GB 64.7 MB/s eta 0:00:10
#    ------------------------------- -------- 2.1/2.7 GB 64.7 MB/s eta 0:00:10
#    ------------------------------- -------- 2.1/2.7 GB 65.5 MB/s eta 0:00:09
#    ------------------------------- -------- 2.2/2.7 GB 66.0 MB/s eta 0:00:09
#    -------------------------------- ------- 2.2/2.7 GB 66.2 MB/s eta 0:00:09
#    -------------------------------- ------- 2.2/2.7 GB 66.2 MB/s eta 0:00:08
#    -------------------------------- ------- 2.2/2.7 GB 65.5 MB/s eta 0:00:08
#    -------------------------------- ------- 2.2/2.7 GB 64.5 MB/s eta 0:00:08
#    -------------------------------- ------- 2.2/2.7 GB 64.0 MB/s eta 0:00:08
#    -------------------------------- ------- 2.2/2.7 GB 62.1 MB/s eta 0:00:08
#    -------------------------------- ------- 2.2/2.7 GB 59.4 MB/s eta 0:00:09
#    --------------------------------- ------ 2.2/2.7 GB 58.2 MB/s eta 0:00:09
#    --------------------------------- ------ 2.3/2.7 GB 57.0 MB/s eta 0:00:09
#    --------------------------------- ------ 2.3/2.7 GB 56.6 MB/s eta 0:00:08
#    --------------------------------- ------ 2.3/2.7 GB 56.4 MB/s eta 0:00:08
#    --------------------------------- ------ 2.3/2.7 GB 56.6 MB/s eta 0:00:08
#    ---------------------------------- ----- 2.3/2.7 GB 57.0 MB/s eta 0:00:08
#    ---------------------------------- ----- 2.3/2.7 GB 57.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 2.4/2.7 GB 58.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 2.4/2.7 GB 64.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 2.4/2.7 GB 64.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 2.4/2.7 GB 64.0 MB/s eta 0:00:05
#    ----------------------------------- ---- 2.4/2.7 GB 63.7 MB/s eta 0:00:05
#    ----------------------------------- ---- 2.4/2.7 GB 62.8 MB/s eta 0:00:05
#    ----------------------------------- ---- 2.4/2.7 GB 63.0 MB/s eta 0:00:05
#    ------------------------------------ --- 2.5/2.7 GB 61.4 MB/s eta 0:00:05
#    ------------------------------------ --- 2.5/2.7 GB 61.0 MB/s eta 0:00:05
#    ------------------------------------ --- 2.5/2.7 GB 60.5 MB/s eta 0:00:05
#    ------------------------------------ --- 2.5/2.7 GB 60.5 MB/s eta 0:00:04
#    ------------------------------------ --- 2.5/2.7 GB 63.5 MB/s eta 0:00:04
#    ------------------------------------ --- 2.5/2.7 GB 66.5 MB/s eta 0:00:04
#    ------------------------------------- -- 2.5/2.7 GB 67.3 MB/s eta 0:00:03
#    ------------------------------------- -- 2.5/2.7 GB 67.9 MB/s eta 0:00:03
#    ------------------------------------- -- 2.6/2.7 GB 67.8 MB/s eta 0:00:03
#    ------------------------------------- -- 2.6/2.7 GB 67.6 MB/s eta 0:00:03
#    -------------------------------------- - 2.6/2.7 GB 66.2 MB/s eta 0:00:03
#    -------------------------------------- - 2.6/2.7 GB 65.0 MB/s eta 0:00:02
#    -------------------------------------- - 2.6/2.7 GB 63.7 MB/s eta 0:00:02
#    -------------------------------------- - 2.6/2.7 GB 63.0 MB/s eta 0:00:02
#    -------------------------------------- - 2.6/2.7 GB 61.8 MB/s eta 0:00:02
#    -------------------------------------- - 2.6/2.7 GB 60.7 MB/s eta 0:00:02
#    -------------------------------------- - 2.6/2.7 GB 58.8 MB/s eta 0:00:02
#    -------------------------------------- - 2.6/2.7 GB 57.2 MB/s eta 0:00:02
#    ---------------------------------------  2.7/2.7 GB 56.2 MB/s eta 0:00:02
#    ---------------------------------------  2.7/2.7 GB 55.5 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 55.0 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 55.5 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.4 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 GB 57.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 GB 34.7 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/torchvision-0.22.1%2Bcu126-cp310-cp310-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 48.6 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/torchaudio-2.7.1%2Bcu126-cp310-cp310-win_amd64.whl (4.2 MB)
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---------------------------------------- 4.2/4.2 MB 31.6 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    -------------------------------------- - 6.0/6.2 MB 33.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 29.2 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Downloading https://download.pytorch.org/whl/Jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 46.5 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision, torchaudio
#
#    ----------------------------------------  0/10 [mpmath]
#    ----------------------------------------  0/10 [mpmath]
#    ----------------------------------------  0/10 [mpmath]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    ---- -----------------------------------  1/10 [sympy]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    -------- -------------------------------  2/10 [networkx]
#    ------------ ---------------------------  3/10 [MarkupSafe]
#    ---------------- -----------------------  4/10 [fsspec]
#    ---------------- -----------------------  4/10 [fsspec]
#    ------------------------ ---------------  6/10 [jinja2]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    -------------------------------- -------  8/10 [torchvision]
#    -------------------------------- -------  8/10 [torchvision]
#    -------------------------------- -------  8/10 [torchvision]
#    -------------------------------- -------  8/10 [torchvision]
#    -------------------------------- -------  8/10 [torchvision]
#    -------------------------------- -------  8/10 [torchvision]
#    -------------------------------- -------  8/10 [torchvision]
#    -------------------------------- -------  8/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchaudio]
#    ------------------------------------ ---  9/10 [torchaudio]
#    ------------------------------------ ---  9/10 [torchaudio]
#    ---------------------------------------- 10/10 [torchaudio]
#
# Successfully installed MarkupSafe-2.1.5 filelock-3.13.1 fsspec-2024.6.1 jinja2-3.1.4 mpmath-1.3.0 networkx-3.3 sympy-1.13.3 torch-2.7.1+cu126 torchaudio-2.7.1+cu126 torchvision-0.22.1+cu126
# Note: you may need to restart the kernel to use updated packages.
# Collecting mace-torch
#   Downloading mace_torch-0.3.13-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: torch>=1.12 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from mace-torch) (2.7.1+cu126)
# Collecting e3nn==0.4.4 (from mace-torch)
#   Downloading e3nn-0.4.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from mace-torch) (2.2.6)
# Collecting opt_einsum (from mace-torch)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: ase in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from mace-torch) (3.25.0)
# Collecting torch-ema (from mace-torch)
#   Downloading torch_ema-0.3-py3-none-any.whl.metadata (415 bytes)
# Collecting prettytable (from mace-torch)
#   Downloading prettytable-3.16.0-py3-none-any.whl.metadata (33 kB)
# Collecting matscipy (from mace-torch)
#   Downloading matscipy-1.1.1-cp310-cp310-win_amd64.whl.metadata (37 kB)
# Collecting h5py (from mace-torch)
#   Downloading h5py-3.14.0-cp310-cp310-win_amd64.whl.metadata (2.7 kB)
# Collecting torchmetrics (from mace-torch)
#   Downloading torchmetrics-1.7.4-py3-none-any.whl.metadata (21 kB)
# Collecting python-hostlist (from mace-torch)
#   Downloading python_hostlist-2.2.2.tar.gz (37 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting configargparse (from mace-torch)
#   Downloading configargparse-1.7.1-py3-none-any.whl.metadata (24 kB)
# Collecting GitPython (from mace-torch)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pyYAML (from mace-torch)
#   Downloading PyYAML-6.0.2-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Collecting tqdm (from mace-torch)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting lmdb (from mace-torch)
#   Downloading lmdb-1.7.2-cp310-cp310-win_amd64.whl.metadata (1.3 kB)
# Collecting orjson (from mace-torch)
#   Downloading orjson-3.11.0-cp310-cp310-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: matplotlib in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from mace-torch) (3.10.3)
# Collecting pandas (from mace-torch)
#   Downloading pandas-2.3.1-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: sympy in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from e3nn==0.4.4->mace-torch) (1.13.3)
# Requirement already satisfied: scipy in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from e3nn==0.4.4->mace-torch) (1.15.3)
# Collecting opt-einsum-fx>=0.1.4 (from e3nn==0.4.4->mace-torch)
#   Downloading opt_einsum_fx-0.1.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from opt-einsum-fx>=0.1.4->e3nn==0.4.4->mace-torch) (25.0)
# Requirement already satisfied: filelock in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from torch>=1.12->mace-torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from torch>=1.12->mace-torch) (4.14.1)
# Requirement already satisfied: networkx in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from torch>=1.12->mace-torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from torch>=1.12->mace-torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from torch>=1.12->mace-torch) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from sympy->e3nn==0.4.4->mace-torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from matplotlib->mace-torch) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from matplotlib->mace-torch) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from matplotlib->mace-torch) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from matplotlib->mace-torch) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from matplotlib->mace-torch) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from matplotlib->mace-torch) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from matplotlib->mace-torch) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from python-dateutil>=2.7->matplotlib->mace-torch) (1.17.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython->mace-torch)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython->mace-torch)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from jinja2->torch>=1.12->mace-torch) (2.1.5)
# Collecting numpy (from mace-torch)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting pytz>=2020.1 (from pandas->mace-torch)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->mace-torch)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: wcwidth in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from prettytable->mace-torch) (0.2.13)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics->mace-torch)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: setuptools in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics->mace-torch) (80.9.0)
# Requirement already satisfied: colorama in c:\users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages (from tqdm->mace-torch) (0.4.6)
# Downloading mace_torch-0.3.13-py3-none-any.whl (202 kB)
# Downloading e3nn-0.4.4-py3-none-any.whl (387 kB)
# Downloading opt_einsum_fx-0.1.4-py3-none-any.whl (13 kB)
# Downloading configargparse-1.7.1-py3-none-any.whl (25 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading h5py-3.14.0-cp310-cp310-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 18.6 MB/s eta 0:00:00
# Downloading lmdb-1.7.2-cp310-cp310-win_amd64.whl (99 kB)
# Downloading matscipy-1.1.1-cp310-cp310-win_amd64.whl (565 kB)
#    ---------------------------------------- 0.0/565.9 kB ? eta -:--:--
#    --------------------------------------- 565.9/565.9 kB 20.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------- ----------------------- 6.6/15.8 MB 28.7 MB/s eta 0:00:01
#    --------------------------------- ------ 13.4/15.8 MB 31.1 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 30.2 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading orjson-3.11.0-cp310-cp310-win_amd64.whl (129 kB)
# Downloading pandas-2.3.1-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    -------------------- ------------------- 5.8/11.3 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 27.2 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading prettytable-3.16.0-py3-none-any.whl (33 kB)
# Downloading PyYAML-6.0.2-cp310-cp310-win_amd64.whl (161 kB)
# Downloading torch_ema-0.3-py3-none-any.whl (5.5 kB)
# Downloading torchmetrics-1.7.4-py3-none-any.whl (963 kB)
#    ---------------------------------------- 0.0/963.5 kB ? eta -:--:--
#    --------------------------------------- 963.5/963.5 kB 22.6 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Building wheels for collected packages: python-hostlist
#   Building wheel for python-hostlist (pyproject.toml): started
#   Building wheel for python-hostlist (pyproject.toml): finished with status 'done'
#   Created wheel for python-hostlist: filename=python_hostlist-2.2.2-py3-none-any.whl size=39774 sha256=3e788860f506a6402a4bd1ecc68308d344908f18f0fc1847d24d9e60592eb9bf
#   Stored in directory: c:\users\yutoml\appdata\local\pip\cache\wheels\56\45\f9\56c56519398ea22fd181ebe8a9542cf4a8bdc03476ec87d0dc
# Successfully built python-hostlist
# Installing collected packages: pytz, python-hostlist, lmdb, tzdata, tqdm, smmap, pyYAML, prettytable, orjson, opt_einsum, numpy, lightning-utilities, configargparse, pandas, h5py, gitdb, torchmetrics, torch-ema, opt-einsum-fx, GitPython, e3nn, matscipy, mace-torch
#
#    ----------------------------------------  0/23 [pytz]
#    ----------------------------------------  0/23 [pytz]
#    ----------------------------------------  0/23 [pytz]
#    - --------------------------------------  1/23 [python-hostlist]
#    ----- ----------------------------------  3/23 [tzdata]
#    ----- ----------------------------------  3/23 [tzdata]
#    ----- ----------------------------------  3/23 [tzdata]
#    ------ ---------------------------------  4/23 [tqdm]
#    ------ ---------------------------------  4/23 [tqdm]
#    ------ ---------------------------------  4/23 [tqdm]
#    ------ ---------------------------------  4/23 [tqdm]
#    ------ ---------------------------------  4/23 [tqdm]
#    -------- -------------------------------  5/23 [smmap]
#    ------------ ---------------------------  7/23 [prettytable]
#    --------------- ------------------------  9/23 [opt_einsum]
#   Attempting uninstall: numpy
#    --------------- ------------------------  9/23 [opt_einsum]
#     Found existing installation: numpy 2.2.6
#    --------------- ------------------------  9/23 [opt_einsum]
#     Uninstalling numpy-2.2.6:
#    --------------- ------------------------  9/23 [opt_einsum]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#       Successfully uninstalled numpy-2.2.6
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ----------------- ---------------------- 10/23 [numpy]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ---------------------- ----------------- 13/23 [pandas]
#    ------------------------ --------------- 14/23 [h5py]
#    ------------------------ --------------- 14/23 [h5py]
#    ------------------------ --------------- 14/23 [h5py]
#    -------------------------- ------------- 15/23 [gitdb]
#    --------------------------- ------------ 16/23 [torchmetrics]
#    --------------------------- ------------ 16/23 [torchmetrics]
#    --------------------------- ------------ 16/23 [torchmetrics]
#    --------------------------- ------------ 16/23 [torchmetrics]
#    --------------------------- ------------ 16/23 [torchmetrics]
#    --------------------------- ------------ 16/23 [torchmetrics]
#    --------------------------- ------------ 16/23 [torchmetrics]
#    --------------------------- ------------ 16/23 [torchmetrics]
#    --------------------------------- ------ 19/23 [GitPython]
#    --------------------------------- ------ 19/23 [GitPython]
#    ---------------------------------- ----- 20/23 [e3nn]
#    ---------------------------------- ----- 20/23 [e3nn]
#    ------------------------------------ --- 21/23 [matscipy]
#    ------------------------------------ --- 21/23 [matscipy]
#    ------------------------------------ --- 21/23 [matscipy]
#    -------------------------------------- - 22/23 [mace-torch]
#    -------------------------------------- - 22/23 [mace-torch]
#    -------------------------------------- - 22/23 [mace-torch]
#    -------------------------------------- - 22/23 [mace-torch]
#    ---------------------------------------- 23/23 [mace-torch]
#
# Successfully installed GitPython-3.1.44 configargparse-1.7.1 e3nn-0.4.4 gitdb-4.0.12 h5py-3.14.0 lightning-utilities-0.14.3 lmdb-1.7.2 mace-torch-0.3.13 matscipy-1.1.1 numpy-1.26.4 opt-einsum-fx-0.1.4 opt_einsum-3.4.0 orjson-3.11.0 pandas-2.3.1 prettytable-3.16.0 pyYAML-6.0.2 python-hostlist-2.2.2 pytz-2025.2 smmap-5.0.2 torch-ema-0.3 torchmetrics-1.7.4 tqdm-4.67.1 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yvl 2024.9.17 requires mp-api, which is not installed.
# yvl 2024.9.17 requires phonopy, which is not installed.
# yvl 2024.9.17 requires pymatgen, which is not installed.
# yvl 2024.9.17 requires scikit-image, which is not installed.
# yvl 2024.9.17 requires scikit-learn, which is not installed.
# yvl 2024.9.17 requires seekpath, which is not installed.
# yvl 2024.9.17 requires typer, which is not installed.

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# %pip uninstall -y cuequivariance cuequivariance-torch cuequivariance-ops-torch-cu12
# %pip cache purge
# %pip install cuequivariance cuequivariance-torch cuequivariance-ops-torch-cu12
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping cuequivariance as it is not installed.
# WARNING: Skipping cuequivariance-torch as it is not installed.
# WARNING: Skipping cuequivariance-ops-torch-cu12 as it is not installed.
# Files removed: 179 (2773.7 MB)
# Note: you may need to restart the kernel to use updated packages.
# Collecting cuequivariance
#   Downloading cuequivariance-0.5.1-py3-none-any.whl.metadata (15 kB)
# Collecting cuequivariance-torch
#   Downloading cuequivariance_torch-0.5.1-py3-none-any.whl.metadata (15 kB)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cuequivariance-ops-torch-cu12 (from versions: none)
# ERROR: No matching distribution found for cuequivariance-ops-torch-cu12

# %%
import warnings
warnings.filterwarnings("ignore")
from mace.cli.run_train import main as mace_run_train_main
import sys
import logging

def train_mace(config_file_path):
    logging.getLogger().handlers.clear()
    sys.argv = ["program", "--config", config_file_path]
    mace_run_train_main()
# Out:
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
train_mace("config-03.yml")
# Out:
# 2025-07-20 17:41:27.505 INFO: ===========VERIFYING SETTINGS===========
# 2025-07-20 17:41:27.506 INFO: MACE version: 0.3.13
# 2025-07-20 17:41:27.507 INFO: CUDA version: 12.6, CUDA device: 0
# 2025-07-20 17:41:27.510 INFO: ===========LOADING INPUT DATA===========
# 2025-07-20 17:41:27.511 INFO: Using heads: ['Default']
# 2025-07-20 17:41:27.512 INFO: Using the key specifications to parse data:
# 2025-07-20 17:41:27.513 INFO: Default: KeySpecification(info_keys={'energy': 'REF_energy', 'stress': 'REF_stress', 'virials': 'REF_virials', 'dipole': 'dipole', 'head': 'head'}, arrays_keys={'forces': 'REF_forces', 'charges': 'REF_charges'})
# 2025-07-20 17:41:27.513 INFO: =============    Processing head Default     ===========
# 2025-07-20 17:41:28.597 INFO: Using isolated atom energies from training file
# 2025-07-20 17:41:28.655 INFO: Training set 1/1 [energy: 1314, stress: 0, virials: 0, dipole components: 0, head: 1314, forces: 1314, charges: 0]
# 2025-07-20 17:41:28.659 INFO: Total Training set [energy: 1314, stress: 0, virials: 0, dipole components: 0, head: 1314, forces: 1314, charges: 0]
# 2025-07-20 17:41:28.660 INFO: No validation set provided, splitting training data instead.
# 2025-07-20 17:41:28.663 INFO: Using random 5% of training set for validation with indices saved in: ./valid_indices_123.txt
# 2025-07-20 17:41:28.669 INFO: Random Split Training set [energy: 1249, stress: 0, virials: 0, dipole components: 0, head: 1249, forces: 1249, charges: 0]
# 2025-07-20 17:41:28.670 INFO: Random Split Validation set [energy: 65, stress: 0, virials: 0, dipole components: 0, head: 65, forces: 65, charges: 0]
# 2025-07-20 17:41:28.671 INFO: Total number of configurations: train=1249, valid=65, tests=[],
# 2025-07-20 17:41:28.691 INFO: Atomic Numbers used: [1, 8]
# 2025-07-20 17:41:28.692 INFO: Atomic Energies used (z: eV) for head Default: {1: -0.15225284, 8: -0.08810633}
# 2025-07-20 17:41:28.693 INFO: Processing datasets for head 'Default'
# 2025-07-20 17:41:34.497 INFO: Combining 1 list datasets for head 'Default'
# 2025-07-20 17:41:34.828 INFO: Head 'Default' training dataset size: 1249
# 2025-07-20 17:41:34.829 INFO: Computing average number of neighbors
# 2025-07-20 17:41:35.997 INFO: Average number of neighbors: 90.85576973170096
# 2025-07-20 17:41:35.998 INFO: During training the following quantities will be reported: energy, forces
# 2025-07-20 17:41:35.999 INFO: ===========MODEL DETAILS===========
# 2025-07-20 17:41:36.715 INFO: Building model
# 2025-07-20 17:41:36.755 INFO: Message passing with 64 channels and max_L=0 (64x0e)
# 2025-07-20 17:41:36.756 INFO: 2 layers, each with correlation order: 3 (body order: 4) and spherical harmonics up to: l=3
# 2025-07-20 17:41:36.757 INFO: 8 radial and 5 basis functions
# 2025-07-20 17:41:36.757 INFO: Radial cutoff: 6.0 A (total receptive field for each atom: 12.0 A)
# 2025-07-20 17:41:36.758 INFO: Distance transform for radial basis functions: None
# 2025-07-20 17:41:36.758 INFO: Hidden irreps: 64x0e
# 2025-07-20 17:41:37.521 INFO: Total number of parameters: 148688
# 2025-07-20 17:41:37.522 INFO:
# 2025-07-20 17:41:37.522 INFO: ===========OPTIMIZER INFORMATION===========
# 2025-07-20 17:41:37.523 INFO: Using ADAM as parameter optimizer
# 2025-07-20 17:41:37.523 INFO: Batch size: 10
# 2025-07-20 17:41:37.524 INFO: Using Exponential Moving Average with decay: 0.99
# 2025-07-20 17:41:37.524 INFO: Number of gradient updates: 12490
# 2025-07-20 17:41:37.525 INFO: Learning rate: 0.01, weight decay: 5e-07
# 2025-07-20 17:41:37.525 INFO: WeightedEnergyForcesLoss(energy_weight=10.000, forces_weight=100.000)
# 2025-07-20 17:41:37.526 INFO: Stage Two (after 75 epochs) with loss function: WeightedEnergyForcesLoss(energy_weight=1000.000, forces_weight=100.000), with energy weight : 1000.0, forces weight : 100.0 and learning rate : 0.001
# 2025-07-20 17:41:37.588 INFO: Using gradient clipping with tolerance=10.000
# 2025-07-20 17:41:37.589 INFO:
# 2025-07-20 17:41:37.589 INFO: ===========TRAINING===========
# 2025-07-20 17:41:37.590 INFO: Started training, reporting errors on validation set
# 2025-07-20 17:41:37.591 INFO: Loss metrics on validation set
# 2025-07-20 17:41:43.487 INFO: Initial: head: Default, loss=72.73289992, MAE_E_per_atom= 4750.60 meV, MAE_F=  522.62 meV / A
# 2025-07-20 18:39:37.828 INFO: Epoch 0: head: Default, loss=0.60615863, MAE_E_per_atom=   50.74 meV, MAE_F=  113.73 meV / A
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_mace("config-03.yml")
#
# Cell In[1], line 10, in train_mace(config_file_path)
#       8 logging.getLogger().handlers.clear()
#       9 sys.argv = ["program", "--config", config_file_path]
# ---> 10 mace_run_train_main()
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\mace\cli\run_train.py:75, in main()
#      71 """
#      72 This script runs the training/fine tuning for mace
#      73 """
#      74 args = tools.build_default_arg_parser().parse_args()
# ---> 75 run(args)
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\mace\cli\run_train.py:778, in run(args)
#     774     logging.info("DRY RUN mode enabled. Stopping now.")
#     775     return
# --> 778 tools.train(
#     779     model=model,
#     780     loss_fn=loss_fn,
#     781     train_loader=train_loader,
#     782     valid_loaders=valid_loaders,
#     783     optimizer=optimizer,
#     784     lr_scheduler=lr_scheduler,
#     785     checkpoint_handler=checkpoint_handler,
#     786     eval_interval=args.eval_interval,
#     787     start_epoch=start_epoch,
#     788     max_num_epochs=args.max_num_epochs,
#     789     logger=logger,
#     790     patience=args.patience,
#     791     save_all_checkpoints=args.save_all_checkpoints,
#     792     output_args=output_args,
#     793     device=device,
#     794     swa=swa,
#     795     ema=ema,
#     796     max_grad_norm=args.clip_grad,
#     797     log_errors=args.error_table,
#     798     log_wandb=args.wandb,
#     799     distributed=args.distributed,
#     800     distributed_model=distributed_model,
#     801     plotter=plotter,
#     802     train_sampler=train_sampler,
#     803     rank=rank,
#     804 )
#     806 logging.info("")
#     807 logging.info("===========RESULTS===========")
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\mace\tools\train.py:222, in train(model, loss_fn, train_loader, valid_loaders, optimizer, lr_scheduler, start_epoch, max_num_epochs, patience, checkpoint_handler, logger, eval_interval, output_args, device, log_errors, swa, ema, max_grad_norm, log_wandb, distributed, save_all_checkpoints, plotter, distributed_model, train_sampler, rank)
#     220 if "ScheduleFree" in type(optimizer).__name__:
#     221     optimizer.train()
# --> 222 train_one_epoch(
#     223     model=model,
#     224     loss_fn=loss_fn,
#     225     data_loader=train_loader,
#     226     optimizer=optimizer,
#     227     epoch=epoch,
#     228     output_args=output_args,
#     229     max_grad_norm=max_grad_norm,
#     230     ema=ema,
#     231     logger=logger,
#     232     device=device,
#     233     distributed=distributed,
#     234     distributed_model=distributed_model,
#     235     rank=rank,
#     236 )
#     237 if distributed:
#     238     torch.distributed.barrier()
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\mace\tools\train.py:370, in train_one_epoch(model, loss_fn, data_loader, optimizer, epoch, output_args, max_grad_norm, ema, logger, device, distributed, distributed_model, rank)
#     368 else:
#     369     for batch in data_loader:
# --> 370         _, opt_metrics = take_step(
#     371             model=model_to_train,
#     372             loss_fn=loss_fn,
#     373             batch=batch,
#     374             optimizer=optimizer,
#     375             ema=ema,
#     376             output_args=output_args,
#     377             max_grad_norm=max_grad_norm,
#     378             device=device,
#     379         )
#     380         opt_metrics["mode"] = "opt"
#     381         opt_metrics["epoch"] = epoch
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\mace\tools\train.py:416, in take_step(model, loss_fn, batch, optimizer, ema, output_args, max_grad_norm, device)
#     412         torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=max_grad_norm)
#     414     return loss
# --> 416 loss = closure()
#     417 optimizer.step()
#     419 if ema is not None:
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\mace\tools\train.py:409, in take_step.<locals>.closure()
#     401 optimizer.zero_grad(set_to_none=True)
#     402 output = model(
#     403     batch_dict,
#     404     training=True,
#    (...)
#     407     compute_stress=output_args["stress"],
#     408 )
# --> 409 loss = loss_fn(pred=output, ref=batch)
#     410 loss.backward()
#     411 if max_grad_norm is not None:
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\mace\modules\loss.py:241, in WeightedEnergyForcesLoss.forward(self, ref, pred, ddp)
#     237 def forward(
#     238     self, ref: Batch, pred: TensorDict, ddp: Optional[bool] = None
#     239 ) -> torch.Tensor:
#     240     loss_energy = weighted_mean_squared_error_energy(ref, pred, ddp)
# --> 241     loss_forces = mean_squared_error_forces(ref, pred, ddp)
#     242     return self.energy_weight * loss_energy + self.forces_weight * loss_forces
#
# File c:\Users\yutoml\.virtualenvs\mace-3.10.11\lib\site-packages\mace\modules\loss.py:124, in mean_squared_error_forces(ref, pred, ddp)
#     120 def mean_squared_error_forces(
#     121     ref: Batch, pred: TensorDict, ddp: Optional[bool] = None
#     122 ) -> torch.Tensor:
#     123     # Repeat per-graph weights to per-atom level.
# --> 124     configs_weight = torch.repeat_interleave(
#     125         ref.weight, ref.ptr[1:] - ref.ptr[:-1]
#     126     ).unsqueeze(-1)
#     127     configs_forces_weight = torch.repeat_interleave(
#     128         ref.forces_weight, ref.ptr[1:] - ref.ptr[:-1]
#     129     ).unsqueeze(-1)
#     130     raw_loss = (
#     131         configs_weight
#     132         * configs_forces_weight
#     133         * torch.square(ref["forces"] - pred["forces"])
#     134     )
#
# KeyboardInterrupt:
